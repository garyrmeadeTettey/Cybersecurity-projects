# %% [markdown]
# <a href="https://colab.research.google.com/github/garyrmeadeTettey/Cybersecurity-projects/blob/main/Data_Encryption_Scrypt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cryptography
# Out:
# ...
#      |████████████████████████████████| 3.6 MB 5.2 MB/s
# ...

# %%
# import required module
from cryptography.fernet import Fernet

# %%
# key generation
key = Fernet.generate_key()

# string the key in a file
with open('filekey.key', 'wb') as filekey:
  filekey.write(key)
print(filekey)
# Out:
# <_io.BufferedWriter name='filekey.key'>

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-840ee40e-3f98-479a-8633-4480931a172b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-840ee40e-3f98-479a-8633-4480931a172b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nba.csv to nba.csv

# %%
print(data_to_load)
# Out:
# {'nba.csv': b"Name,Team,Number,Position,Age,Height,Weight,College,Salary\nAvery Bradley,Boston Celtics,0.0,PG,25.0,6-2,180.0,Texas,7730337.0\nJae Crowder,Boston Celtics,99.0,SF,25.0,6-6,235.0,Marquette,6796117.0\nJohn Holland,Boston Celtics,30.0,SG,27.0,6-5,205.0,Boston University,\nR.J. Hunter,Boston Celtics,28.0,SG,22.0,6-5,185.0,Georgia State,1148640.0\nJonas Jerebko,Boston Celtics,8.0,PF,29.0,6-10,231.0,,5000000.0\nAmir Johnson,Boston Celtics,90.0,PF,29.0,6-9,240.0,,12000000.0\nJordan Mickey,Boston Celtics,55.0,PF,21.0,6-8,235.0,LSU,1170960.0\nKelly Olynyk,Boston Celtics,41.0,C,25.0,7-0,238.0,Gonzaga,2165160.0\nTerry Rozier,Boston Celtics,12.0,PG,22.0,6-2,190.0,Louisville,1824360.0\nMarcus Smart,Boston Celtics,36.0,PG,22.0,6-4,220.0,Oklahoma State,3431040.0\nJared Sullinger,Boston Celtics,7.0,C,24.0,6-9,260.0,Ohio State,2569260.0\nIsaiah Thomas,Boston Celtics,4.0,PG,27.0,5-9,185.0,Washington,6912869.0\nEvan Turner,Boston Celtics,11.0,SG,27.0,6-7,220.0,Ohio State,3425510.0\nJames 
# ...

# %% [markdown]
# data before encryption

# %%
# opening the key
with open('filekey.key', 'rb') as filekey:
	key = filekey.read()

# using the generated key
fernet = Fernet(key)

# opening the original file to encrypt
with open('nba.csv', 'rb') as file:
	original = file.read()
	
# encrypting the file
encrypted = fernet.encrypt(original)

# opening the file in write mode and
# writing the encrypted data
with open('nba.csv', 'wb') as encrypted_file:
	encrypted_file.write(encrypted)

# %%
print(encrypted, end='\n')
# Out:
# b'gAAAAABiE2i_7fK2nP_l2rdkdZsF2t9IFfFHpfT_4dqHBapZn1n3DOsGlCXFQiQM1UcQ2Rl9op5hzQFkrHuZgwNxWDeEQfsngC2elmAOn6HWU09-lVsfE-PzfVr1OOO2xJlo0K2a1bT87ygmjwTtDoCOPtgcZ-dc6I14qw8YaFVzCYTPInaaZu6PVmuMpp8ouiJdTxheRJtcxU7TlflNgpOms7Fm9IIGdV7tCrGN6uqR4GKhHAnlFyl480THOTMfoXoNXMRKnknxhAEASzcFR-RBIfuTr_kaJuYPRg8uxBoUiflhCaUnsDLC8pBdN9FrV0-SgzRNaUR1_om7WjRJWBFYTkV-hehpB76ACkoGUbfyk-4jXKn-y7tBKvsTGXuagb64KbjEYHD1C87NPtY85V3SmqC4Lg64f2R-PLC5Pa7W7vl_CQN_W-A30CUOz9zCS68GT5F2B7k6hZ8-h1hi7v2iYXRFTjCZxDIYF8U1kMvtLG3xHJ-zH1lSqjb2xyHloQoeT2VQQ04sJA3h2LAvxUY9q7R3WKtXvHpytbZ7YdRJ82oneqQkivYOmiqdLhRIjbluI_d78E-JAvCNDKBH6h5zVQRMyR7SXolhSQXy1hPsxuYa2H1r_63yT3q0nljyOk-ZHZY1UcjFVovUjTaav38MLeZrZAY8o088sEz7ueQKndMf9rRlTvc-qse9nSVPYSLjubBDn7WotX6WtDlYZzpYXusvUgepNujI30u3_YaYPRMbeCEB3njY0ZU7CxwyY5zyVykB12khBgYE2Ne84hExqdcBIxJWLxBprPjiIQWSBxS1PG02icL9B2w5xs0AvY6dqrht-YRUIzx-K7JOGCnaYtpFH7_7-np14Spp-GCHpq_YSTNTU-MteBXOMTvjQ6WTNqlDD59d_edzyHDXv6JMoVu3QCFlAtBlAD-j3YDqXHYuh0h_XvMzpjaploMAXYe6T4bLq_24FeO5n0vIZcpkaWuNxaO6CrCS
# ...

# %% [markdown]
# Data after encryption

# %%
# using the key
fernet = Fernet(key)

# opening the encrypted file
with open('nba.csv', 'rb') as enc_file:
	encrypted = enc_file.read()

# decrypting the file
decrypted = fernet.decrypt(encrypted)

# opening the file in write mode and
# writing the decrypted data
with open('nba.csv', 'wb') as dec_file:
	dec_file.write(decrypted)

# %% [markdown]
# Script to decrpyt the the encrypted data

# %%
print(decrypted)
# Out:
# b"Name,Team,Number,Position,Age,Height,Weight,College,Salary\nAvery Bradley,Boston Celtics,0.0,PG,25.0,6-2,180.0,Texas,7730337.0\nJae Crowder,Boston Celtics,99.0,SF,25.0,6-6,235.0,Marquette,6796117.0\nJohn Holland,Boston Celtics,30.0,SG,27.0,6-5,205.0,Boston University,\nR.J. Hunter,Boston Celtics,28.0,SG,22.0,6-5,185.0,Georgia State,1148640.0\nJonas Jerebko,Boston Celtics,8.0,PF,29.0,6-10,231.0,,5000000.0\nAmir Johnson,Boston Celtics,90.0,PF,29.0,6-9,240.0,,12000000.0\nJordan Mickey,Boston Celtics,55.0,PF,21.0,6-8,235.0,LSU,1170960.0\nKelly Olynyk,Boston Celtics,41.0,C,25.0,7-0,238.0,Gonzaga,2165160.0\nTerry Rozier,Boston Celtics,12.0,PG,22.0,6-2,190.0,Louisville,1824360.0\nMarcus Smart,Boston Celtics,36.0,PG,22.0,6-4,220.0,Oklahoma State,3431040.0\nJared Sullinger,Boston Celtics,7.0,C,24.0,6-9,260.0,Ohio State,2569260.0\nIsaiah Thomas,Boston Celtics,4.0,PG,27.0,5-9,185.0,Washington,6912869.0\nEvan Turner,Boston Celtics,11.0,SG,27.0,6-7,220.0,Ohio State,3425510.0\nJames Young,Boston
# ...
